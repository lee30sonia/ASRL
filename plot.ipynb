# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from scipy import stats
import cv2
import sys
import scipy.io as sio

plt.figure(figsize=[2,2]);


ratemaps = sio.loadmat('exp2-noisy/goal.mat', appendmat=False)['r']
#ratemaps2 = sio.loadmat('exp-noisy/mgc.mat', appendmat=False)['r']


plt.subplot(1, 1, 1)
plt.imshow(np.flipud(ratemaps[0]), interpolation = 'gaussian')
plt.gca().set_xticklabels([])
plt.gca().set_yticklabels([])
plt.gca().set_xticks([])
plt.gca().set_yticks([])

#plt.subplot(2, 2, 3)
#plt.imshow(np.flipud(ratemaps[360]), interpolation = 'gaussian')
#plt.gca().set_xticklabels([])
#plt.gca().set_yticklabels([])
#plt.gca().set_xticks([])
#plt.gca().set_yticks([])
#
#plt.subplot(2, 2, 2)
#plt.imshow(np.flipud(ratemaps2[0]), interpolation = 'gaussian')
#plt.gca().set_xticklabels([])
#plt.gca().set_yticklabels([])
#plt.gca().set_xticks([])
#plt.gca().set_yticks([])
#
#plt.subplot(2, 2, 4)
#plt.imshow(np.flipud(ratemaps2[360]), interpolation = 'gaussian')
#plt.gca().set_xticklabels([])
#plt.gca().set_yticklabels([])
#plt.gca().set_xticks([])
#plt.gca().set_yticks([])

#plt.show();
plt.title("Goal cell")
plt.savefig('goal.png', dpi=200)
